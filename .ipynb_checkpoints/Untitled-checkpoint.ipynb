# %%
import torch
from torchvision import transforms
from torchvision import datasets

# %%
from lib import train_history

# %%
data_name = 'data/combine'
test_data_name = 'data/eye_test'

# %%
input_size=128
batch_size = 2

# %%
# data_loader
train_transform = transforms.Compose([
        transforms.Resize((input_size, 2*input_size)),
#         transforms.ColorJitter(0.1,0.1,0.1,0.1),
        transforms.ToTensor(),
        transforms.Normalize(mean=(0.5, 0.5, 0.5), std=(0.5, 0.5, 0.5))
])

test_transform = transforms.Compose([
        transforms.Resize((input_size, input_size)),
#         transforms.ColorJitter(0.1,0.1,0.1,0.1),
        transforms.ToTensor(),
        transforms.Normalize(mean=(0.5, 0.5, 0.5), std=(0.5, 0.5, 0.5))
])

# train_loader = utils.data_load(data_name, 'train', train_transform, batch_size, shuffle=False, drop_last=True)
# test_loader = utils.data_load(data_name, 'test', train_transform, batch_size, shuffle=False, drop_last=True)
test_loader = torch.utils.data.DataLoader(datasets.ImageFolder(test_data_name, test_transform), batch_size=1, shuffle=True, drop_last=True)
train_loader = torch.utils.data.DataLoader(datasets.ImageFolder(data_name, train_transform), batch_size=batch_size, shuffle=True, drop_last=True)

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
import os
# %matplotlib inline

# %%
eye_files = os.listdir(os.path.join(test_data_name,'test'))
for e in eye_files:
    img = cv2.imread(os.path.join(test_data_name,'test',e))
    print(img.shape)
    break
# Out:
# (400, 480, 3)

# %%
for d, _ in train_loader:
    print(d.shape)
    x = d[:,:,:,:input_size]
    y = d[:,:,:,input_size:]
    x = x[0]
    y = y[0]
    x = x.numpy().transpose(1, 2, 0)
    x = cv2.flip(x,1)
    y = y.numpy().transpose(1,2,0)
    y= cv2.flip(y,1)
    d = np.concatenate((x,y),axis=1)
    plt.imshow((d+1)/2)
    plt.show()
    
    d = torch.from_numpy(d.transpose(2,0,1))
    print(d.shape)
    break
# Out:
# torch.Size([2, 3, 128, 256])
# torch.Size([3, 128, 256])

# %%
    d = np.concatenate
